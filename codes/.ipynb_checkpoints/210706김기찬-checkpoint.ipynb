# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import plotly.graph_objects as go
import re

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
# !conda install plotly

# %%
for i in tqdm(range(100)):
    pass
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
df_necessity = pd.concat([
    pd.read_csv('../datas/huge/생필품 농수축산물 가격 정보(2020년).csv', encoding='cp949'),
    pd.read_csv('../datas/huge/생필품 농수축산물 가격 정보(2019년).csv', encoding='cp949'),
    pd.read_csv('../datas/huge/생필품 농수축산물 가격 정보(2018년).csv', encoding='cp949'),
    pd.read_csv('../datas/huge/생필품 농수축산물 가격 정보(2013년_2017년).csv', encoding='cp949')
])
df_population = pd.read_csv('../datas/huge/서울시 우리마을가게 상권분석서비스(상권-생활인구).csv', encoding='cp949')
df_sales = pd.concat([
    pd.read_csv('../datas/huge/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2019.csv', encoding='cp949'),
    pd.read_csv('../datas/huge/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2018.csv', encoding='cp949'),
    pd.read_csv('../datas/huge/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2017.csv', encoding='cp949'),
    pd.read_csv('../datas/huge/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2016.csv', encoding='cp949'),
    pd.read_csv('../datas/huge/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2015.csv', encoding='cp949'),
    pd.read_csv('../datas/huge/서울시 우리마을가게 상권분석서비스(상권-추정매출)_2014.csv', encoding='cp949')
])
df_market_address = pd.read_csv('../datas/서울 전통시장 주소.csv', encoding='cp949')
df_supermarket_address = pd.read_csv('../datas/서울 대형마트 주소.csv', encoding='cp949')

# %% [markdown]
# ### 각 데이터 샘플

# %%
df_necessity.head()
# Out:
#       일련번호  시장/마트 번호   시장/마트 이름  품목 번호       품목 이름     실판매규격  가격(원)     년도-월  \
# 0  1621162         1       통인시장    309  양파(1.5kg망)       1kg   2000  2020-12
# 1  1628949       228     방배종합시장    277          호박    1개268g   1500  2020-12
# 2  1626799        51  NC백화점 불광점     18         닭고기  1마리(1kg)   8990  2020-12
# 3  1630920       223   홈플러스 목동점    278         쇠고기      600g  35982  2020-12
# 4  1622882         1       통인시장    309  양파(1.5kg망)       1kg   2000  2020-12
#
#           비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 0     국내산,무안                  1              전통시장  110000    종로구  2020-12-21
# 1  국내산/인큐베이터                  1              전통시장  650000    서초구  2020-12-21
# 2      올품 토종                  2              대형마트  380000    은평구  2020-12-21
# 3  국내산(음성)농협                  2              대형마트  470000    양천구  2020-12-21
# 4     국내산,무안                  1              전통시장  110000    종로구  2020-12-21

# %%
df_sales.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0     2019         1        A       골목상권  1000985     암사길  CS200003
# 1     2019         1        A       골목상권  1000267  돌곶이로8길  CS200037
# 2     2019         1        R       전통시장  1001445    영도시장  CS300027
# 3     2019         1        A       골목상권  1000789  난곡로24길  CS300017
# 4     2019         1        A       골목상권  1000930  언주로81길  CS200001
#
#   서비스_업종_코드_명  분기당_매출_금액  분기당_매출_건수  ...  시간대_건수~24_매출_건수  남성_매출_건수  여성_매출_건수  \
# 0        예술학원   20061598        125  ...                0        93        32
# 1         노래방     510636         21  ...                8         4        17
# 2        섬유제품    4038928         33  ...                0        17         0
# 3      시계및귀금속    5085873         10  ...                0         5         5
# 4      일반교습학원     527027         53  ...               53        53         0
#
#    연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  \
# ...

# %%
df_population.head()
# Out:
#    기준 년코드  기준_분기_코드 상권_구분_코드  상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0    2020         4        U        관광특구  1001496             강남 마이스 관광특구
# 1    2020         4        U        관광특구  1001495                 잠실 관광특구
# 2    2020         4        U        관광특구  1001494              종로?청계 관광특구
# 3    2020         4        U        관광특구  1001493            동대문패션타운 관광특구
# 4    2020         4        U        관광특구  1001492  명동 남대문 북창동 다동 무교동 관광특구
#
#    총_생활인구_수  남성_생활인구_수  여성_생활인구_수  연령대_10_생활인구_수  ...  \
# 0     90836      46313      44523           4351  ...
# 1   2956754    1445027    1511727         248574  ...
# 2   3738997    2060445    1678551          96484  ...
# 3   3058361    1494579    1563782          99823  ...
# 4   3569497    1853999    1715498          81863  ...
#
#    여성연령대_60_이상_토요일시간대_3_생활인구_수  여성연령대_60_이상_토요일시간대_4_생활인구_수  \
# 0                          142                          140
# 1                         5398                         5785
# ...

# %%
df_market_address.head()
# Out:
#    자치구 코드 자치구명           전통시장명          주소명         위도          경도
# 0      22  은평구            갈현시장   갈현동 424-16  37.623587  126.917385
# 1      12  동작구            강남시장      상도동 488  37.518749  127.020640
# 2       1  강남구            강남시장    신사동510-11  37.496746  126.953488
# 3       1  강남구       강남역 지하도상가     역삼동821-1  37.498595  127.028026
# 4      15  서초구  강남터미널지하도상점가1구역  서초구 반포동 163  37.500478  126.986060

# %% [markdown]
# ### 대형마트에 대한 정보도 유동인구, 매출 데이터에 있을까?
# - 역에 있는 대형마트는 역에 있는 정보를 사용할 수 있지만, 역 유동인구 = 대형마트 유동인구는 지나친 확대해석이다
# - 역에 없는 대형마트는 검색해도 안나온다

# %%
df_population[df_population['상권_코드_명'].str.contains('불광')]
# Out:
#        기준 년코드  기준_분기_코드 상권_구분_코드  상권_구분_코드_명    상권_코드       상권_코드_명  총_생활인구_수  \
# 245      2020         4        D        발달상권  1001250  서울 은평구 불광역_3    404002
# 246      2020         4        D        발달상권  1001249  서울 은평구 불광역_2    524727
# 247      2020         4        D        발달상권  1001248  서울 은평구 불광역_1    288839
# 1101     2020         4        A        골목상권  1000394          불광천길   1297473
# 1740     2020         3        D        발달상권  1001250  서울 은평구 불광역_3    417210
# ...       ...       ...      ...         ...      ...           ...       ...
# 39046    2014         2        D        발달상권  1001248  서울 은평구 불광역_1    557811
# 39898    2014         2        A        골목상권  1000394          불광천길    443065
# 40531    2014         1        D        발달상권  1001249  서울 은평구 불광역_2    323435
# 40532    2014         1        D        발달상권  1001248  서울 은평구 불광역_1    640888
# 41384    2014         1        A        골목상권  1000394          불광천길    391892
#
# ...

# %%
df_sales[df_sales['상권_코드_명'].str.contains('불광')]
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  \
# 332        2019         1        D       발달상권  1001248  서울 은평구 불광역_1
# 492        2019         1        A       골목상권  1000394          불광천길
# 743        2019         1        D       발달상권  1001249  서울 은평구 불광역_2
# 746        2019         1        D       발달상권  1001249  서울 은평구 불광역_2
# 930        2019         1        D       발달상권  1001248  서울 은평구 불광역_1
# ...         ...       ...      ...        ...      ...           ...
# 160853     2014         4        A       골목상권  1000394          불광천길
# 161987     2014         4        D       발달상권  1001248  서울 은평구 불광역_1
# 162019     2014         4        D       발달상권  1001250  서울 은평구 불광역_3
# 162020     2014         4        D       발달상권  1001250  서울 은평구 불광역_3
# 162053     2014         4        D       발달상권  1001248  서울 은평구 불광역_1
#
#        서비스_업종_코드   서비스_업종_코드_명  분기당_매출_금액  분기당_매출_건수  ...  시간대_건수~24_매출_건수  \
# ...

# %% [markdown]
# # 여기서부터 생필품, 매출, 시장주소 데이터의 내용이 바뀜

# %% [markdown]
# ### 전통시장만 남겨놓기

# %%
# necessity, sales에 전통시장 관련 행만 남김
df_necessity = df_necessity[df_necessity['시장유형 구분(시장/마트) 이름']=='전통시장']
df_sales = df_sales[df_sales['상권_구분_코드_명']=='전통시장']

# %% [markdown]
# ### 생필품, 매출, 시장주소 데이터에서 시장이름 데이터 들여다보기

# %%
# 생필품
necessity_markets = df_necessity['시장/마트 이름'].unique()
print(len(necessity_markets), necessity_markets)
print([necessity_market for necessity_market in necessity_markets if not re.search('시장', necessity_market)])
# Out:
# 53 ['통인시장' '방배종합시장' '방학동도깨비시장' '장위골목시장' '신창시장' '마포농수산물시장' '동원시장' '광장시장'
#  '남성시장' '금남시장' '뚝도시장' '후암시장' '청량리종합시장' '남문시장' '남구로시장' '신영시장' '고척근린시장'
#  '용문시장' '대림시장' '영등포전통시장' '망원시장' '영천시장' '인왕시장' '신원시장(신림1동)' '자양골목시장'
#  '수유재래시장' '경동시장' '우림시장' '송화시장' '대림중앙시장' '목3동시장' '공릉동 도깨비시장' '돈암제일시장'
#  '원당종합시장' '남대문시장' '청담삼익시장' '현대시장' '둔촌역전통시장' '서울중앙시장' '노룬산골목시장' '화곡본동시장'
#  '방이시장' '대조시장' '도곡시장' '마천중앙시장' '관악신사시장(신림4동)' '암사종합시장' '상계중앙시장' '숭인시장'
#  '방림시장' '구로시장' '공릉동도깨비시장' '영동시장']
# []

# %%
# 매출
sales_markets = df_sales['상권_코드_명'].unique()
print(len(sales_markets), sales_markets)
print([sales_market for sales_market in sales_markets if not re.search('시장', sales_market)])
# Out:
# 226 ['영도시장' '암사종합시장' '서울약령시장' '경동시장' '답십리시장' '이경시장' '뚝도시장' '남문시장' '남대문시장'
#  '방천골목시장' '이촌종합시장' '신중부시장' '현대시장' '상계중앙시장' '평화시장' '만리시장' '숭인시장' '서울중앙시장'
#  '망원시장' '백학시장' '망원월드컵시장' '광장시장' '신흥시장' '장미원골목시장' '약수시장' '신월3동골목시장'
#  '성동용답상가시장' '공덕시장' '한아름시장' '노룬산골목시장' '수일시장' '중곡제일시장' '양지골목시장' '신성골목시장'
#  '자양골목시장' '능동로골목시장' '동부골목시장' '면목골목시장' '사가정시장' '우이시장' '관악신사시장' '우림골목시장'
#  '태능시장' '동원시장' '장위전통시장' '상도4동도깨비골목시장' '솔샘시장' '정릉시장' '상도전통시장' '정릉아리랑시장'
#  '길음시장' '인왕시장' '노량진중앙시장' '영천시장' '목2동시장' '번동북부골목시장' '성대시장' '동평화시장' '신영시장'
#  '방산종합시장' '신월6동골목시장' '모래내시장' '남성역골목시장' '길동복조리시장' '흑석시장' '전농로터리시장' '동진시장'
#  '돈암제일시장' '까치산시장' '합동(새벽)시장' '영진시장A동' '대원종합시장' '새마을시장' '용문전통시장' '화곡본동시장'
#  '신원시장' '신림중앙시장' '봉일시장' '신림종합시장' '신수시장' '남성사계시장' '봉천중앙시장' '창동신창시장'
#  '명일골목시장' '고덕전통시장' '강남시장_강남' '우림시장' '인헌시장' '금남시장' '성내골목시장' '고척근린시장'
#  '신정제일시장' '천호시장' '동묘시장' '신도봉시장' '보광시장' '남부골목시장' '송화골목시장' '미성동도깨비시장'
#  '창신골목시장' '회기시장' '답십리현대시장' '백운시장' '상계시장' '화곡중앙골목시장' '본동인정시장' '영등포전통시장'
# ...

# %%
# 시장이름
market_address_markets = df_market_address['전통시장명'].unique()
print(len(market_address_markets), market_address_markets)
# Out:
# 327 ['갈현시장' '강남시장' '강남역 지하도상가' '강남터미널지하도상점가1구역' '강남터미널지하도상점가2구역'
#  '강남터미널지하도상점가3구역' '강북종합골목시장' '강북종합시장' '개봉중앙시장' '개봉프라자' '개포2동 중심상가'
#  '경동광성상가' '경동시장' '경창시장' '고덕전통시장' '고속터미널 지하철역 상점가 ' '고척근린시장' '고척프라자' '공덕시장'
#  '공릉동 도깨비시장' '공무원연금매장 상록스토아 개포점' '공항시장' '관악신사시장(신림4동)' '관악종합시장' '광성시장'
#  '광장골목시장' '광장시장' '광희시장' '구로시장' '구의시장' '굽은다리골목시장' '금남시장' '금천교시장' '길동골목시장'
#  '길음시장' '까치산시장' '깡통시장(제기상가번영회)' '낙성대 시장(봉천7동)' '낙원상가' '낙원지하시장(대일상가)'
#  '남구로시장(구 구로자율시장)' '남대문로 지하상가' '남대문시장' '남문시장' '남부골목시장' '남부종합시장' '남부화곡시장'
#  '남서울상가' '남평화시장' '노룬산골목시장' '노룬산시장' '녹번시장' '논현종합시장' '능동로골목시장' '답십리시장'
#  '답십리현대시장' '대림골목시장' '대림시장' '대림중앙시장' '대명시장' '대명시장 및 주변상점가' '대신시장' '대원종합시장'
#  '대조시장' '도림시장' '도선동상점가' '도화동 상점가' '돈암제일시장' '동남상가' '동대문문구완구종합시장' '동대문상가A동'
#  '동대문상가B동' '동대문상가C동' '동대문종합시장' '동대문종합시장D동상가' '동대문지하쇼핑센터' '동문시장' '동부골목시장'
#  '동부시장' '동부청과시장' '동북시장' '동서시장' '동서울시장' '동성타워프라자' '동소문 스카이상가' '동원골목시장'
#  '동원시장' '동진시장' '동평화시장' '동화시장' '두암시장' '둔촌역전통시장' '등마루시장' '뚝도시장' '로데오거리상점가'
# ...

# %% [markdown]
# ### 생필품, 매출, 시장주소 데이터에서 시장이름이 같으면 코드도 같은가?

# %%
df_necessity.groupby(['시장/마트 이름', '년도-월', '품목 번호', '실판매규격', '비고']).count()[['시장/마트 번호']]
# Out:
#                                           시장/마트 번호
# 시장/마트 이름 년도-월    품목 번호 실판매규격     비고
# 경동시장     2013-01 24    1망(1.7kg) 무안              1
#                  58    600g(1등급) 국내산             1
#                  134   10개       국내산             1
#                  152   1마리(35cm) 특대              1
#                  202   600g      국내산             1
# ...                                            ...
# 후암시장     2020-12 312   1개        청원생명            1
#                  315   1마리 45cm  러시아산 냉동         1
#                        1마리 45cm  러시아산 냉동         5
#                  320   30개       국내산 참사랑         3
#                                  참사랑             3
#
# [80247 rows x 1 columns]

# %%
df_necessity.groupby(['시장/마트 번호', '년도-월', '품목 번호', '실판매규격']).count()['시장/마트 이름'].unique()
# Out:
# array([ 1,  6,  3,  2,  5,  7,  4,  8,  9, 10], dtype=int64)

# %%
print(len(df_necessity['시장/마트 번호'].unique()))
print(len(df_necessity['시장/마트 이름'].unique()))
# df_necessity[df_necessity['일련번호'] == 1519524]
for num in df_necessity['시장/마트 번호'].unique():
    df_nessity_market = df_necessity[df_necessity['시장/마트 번호'] == num]
    print(df_nessity_market['시장/마트 이름'].unique())
# Out:
# 52
# 53
# ['통인시장']
# ['방배종합시장']
# ['방학동도깨비시장']
# ['장위골목시장']
# ['신창시장']
# ['마포농수산물시장']
# ['동원시장']
# ['광장시장']
# ['남성시장']
# ['금남시장']
# ['뚝도시장']
# ['후암시장']
# ['청량리종합시장']
# ['남문시장']
# ['남구로시장' '구로시장']
# ['신영시장']
# ['고척근린시장']
# ['용문시장']
# ['대림시장']
# ['영등포전통시장']
# ['망원시장']
# ['영천시장']
# ['인왕시장']
# ['신원시장(신림1동)']
# ['자양골목시장']
# ['수유재래시장']
# ['경동시장']
# ['우림시장']
# ['송화시장']
# ['대림중앙시장']
# ['목3동시장']
# ['공릉동 도깨비시장' '공릉동도깨비시장']
# ['돈암제일시장']
# ['원당종합시장']
# ['남대문시장']
# ['청담삼익시장']
# ['현대시장']
# ['둔촌역전통시장']
# ['서울중앙시장']
# ['노룬산골목시장']
# ['화곡본동시장']
# ['방이시장']
# ['대조시장']
# ['도곡시장']
# ['마천중앙시장']
# ['관악신사시장(신림4동)']
# ['암사종합시장']
# ['상계중앙시장']
# ['숭인시장']
# ['방림시장']
# ['구로시장']
# ['영동시장']

# %%
df_market_address[df_market_address['전통시장명'].str.contains('구로시장')]
# Out:
#     자치구 코드 자치구명            전통시장명         주소명         위도          경도
# 29       7  구로구             구로시장  구로동  736-1  37.488535  126.885264
# 41       7  구로구  남구로시장(구 구로자율시장)  구로동 730-27  37.490481  126.885048

# %%
df_necessity[df_necessity['시장/마트 이름'].str.contains('구로시장')][['시장/마트 이름', '시장/마트 번호']].drop_duplicates()
# Out:
#        시장/마트 이름  시장/마트 번호
# 1273      남구로시장       108
# 108361     구로시장       202
# 52643      구로시장       108

# %%
df_necessity[(df_necessity['시장/마트 이름'].str.contains('구로시장'))&(df_necessity['년도-월']=='2013-12')][['시장/마트 이름', '시장/마트 번호', '년도-월']].drop_duplicates()
# Out:
#       시장/마트 이름  시장/마트 번호     년도-월
# 78474     구로시장       202  2013-12

# %%
df_necessity[(df_necessity['시장/마트 이름'].str.contains('구로시장'))&(df_necessity['년도-월']=='2015-12')][['시장/마트 이름', '시장/마트 번호', '년도-월']].drop_duplicates()
# Out:
#       시장/마트 이름  시장/마트 번호     년도-월
# 40047     구로시장       202  2015-12
# 40367    남구로시장       108  2015-12

# %%
df_necessity[(df_necessity['시장/마트 이름']=='구로시장')&(df_necessity['시장/마트 번호']==108)][['시장/마트 이름', '시장/마트 번호', '년도-월']].drop_duplicates()
# Out:
#       시장/마트 이름  시장/마트 번호     년도-월
# 52643     구로시장       108  2015-04
# 89127     구로시장       108  2013-05

# %%
df_necessity[(df_necessity['시장/마트 이름'].str.contains('구로시장'))&(df_necessity['년도-월']=='2015-04')]
# Out:
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호         품목 이름       실판매규격  가격(원)  \
# 52643  749793       108     구로시장     28            사과          1개   2000
# 52644  749794       108     구로시장    284         배(중품)          1개   3000
# 52645  749795       108     구로시장     26            배추         1포기   3000
# 52646  749796       108     구로시장     25             무          1개   1000
# 52647  749797       108     구로시장    272       양파(작은망)          1망   2000
# 52648  749798       108     구로시장     23            상추   1봉지(400g)   1000
# 52649  749799       108     구로시장     22            오이          1개    500
# 52650  749800       108     구로시장    277            호박          1개   1000
# 52651  749801       108     구로시장     58   쇠고기(한우,불고기)   600g(1등급)  19400
# 52652  749802       108     구로시장    202    돼지고기(생삼겹살)        600g  10800
# 52653  749803       108     구로시장    283       닭고기(육계)  1마리(1.2kg)   5000
# 52654  749804       108     구로시장     17            달걀         10개   1500
# ...

# %%
# ['남구로시장' '구로시장']
# ['공릉동 도깨비시장' '공릉동도깨비시장']
# 위 문제들 해결
df_necessity.loc[df_necessity['시장/마트 번호']==108, '시장/마트 이름'] = '남구로시장'
df_necessity.loc[df_necessity['시장/마트 이름']=='공릉동도깨비시장', '시장/마트 이름'] = '공릉동 도깨비시장'

# %%
df_necessity[df_necessity['시장/마트 이름']=='공릉동 도깨비시장']
# Out:
#           일련번호  시장/마트 번호   시장/마트 이름  품목 번호       품목 이름      실판매규격  가격(원)  \
# 2689   1621745        96  공릉동 도깨비시장    260  조기(냉동,수입산)    1마리25cm   6000
# 2691   1630718        96  공릉동 도깨비시장    254  오징어(생물,국산)    1마리25cm   6000
# 2693   1627810        96  공릉동 도깨비시장    171     달걀(10개)        10개   3000
# 2753   1623570        96  공릉동 도깨비시장    266  고등어(생물,국산)    1마리30cm   5000
# 2815   1621737        96  공릉동 도깨비시장    310    상추(100g)       100g    600
# ...        ...       ...        ...    ...         ...        ...    ...
# 96972   403788        96  공릉동 도깨비시장    134      달걀(왕란)        10개   2500
# 96973   403789        96  공릉동 도깨비시장    260  조기(냉동,수입산)  1마리(20cm)   4000
# 96974   403790        96  공릉동 도깨비시장    152  명태(러시아,냉동)  1마리(45cm)      0
# 96975   403791        96  공릉동 도깨비시장    256  오징어(냉동,국산)  1마리(25cm)   3000
# 96976   403792        96  공릉동 도깨비시장    266  고등어(생물,국산)  1마리(30cm)   3000
#
#           년도-월       비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# ...

# %%
df_necessity[df_necessity['시장/마트 번호']==108][['시장/마트 번호', '시장/마트 이름']].drop_duplicates()
# Out:
#       시장/마트 번호 시장/마트 이름
# 1273       108    남구로시장

# %%
print(len(df_necessity['시장/마트 번호'].unique()))
print(len(df_necessity['시장/마트 이름'].unique()))
# df_necessity[df_necessity['일련번호'] == 1519524]
for name in df_necessity['시장/마트 이름'].unique():
    df_nessity_market = df_necessity[df_necessity['시장/마트 이름'] == name]
    print(df_nessity_market['시장/마트 번호'].unique())
# Out:
# 52
# 52
# [1]
# [228]
# [25]
# [14]
# [26]
# [121]
# [91]
# [55]
# [127]
# [72]
# [73]
# [62]
# [84]
# [115]
# [108]
# [103]
# [109]
# [10]
# [49]
# [20]
# [120]
# [32]
# [31]
# [134]
# [78]
# [66]
# [85]
# [90]
# [38]
# [19]
# [102]
# [96]
# [13]
# [133]
# [11]
# [215]
# [114]
# [205]
# [199]
# [212]
# [213]
# [146]
# [219]
# [216]
# [145]
# [207]
# [151]
# [210]
# [221]
# [217]
# [202]
# [197]

# %%
# 1만 있으면 같은 것
df_sales.groupby(['상권_코드_명', '기준_년_코드', '기준_분기_코드', '서비스_업종_코드']).count()['상권_코드'].unique()
# Out:
# array([1], dtype=int64)

# %%
df_market_address.groupby('전통시장명').count()['주소명']
# Out:
# 전통시장명
# 갈현시장              1
# 강남시장              2
# 강남역 지하도상가         1
# 강남터미널지하도상점가1구역    1
# 강남터미널지하도상점가2구역    1
#                  ..
# 화곡중앙시장            1
# 화양제일골목시장          1
# 회기시장              1
# 회현지하도상가           1
# 후암시장              1
# Name: 주소명, Length: 327, dtype: int64

# %%
# 강남시장의 경우 동일이름 다른지역에 2개 있음
# 하지만 생필품 데이터에 강남시장이 없어 넘어가도 됨
df_market_address[df_market_address['전통시장명'] == '강남시장']
# Out:
#    자치구 코드 자치구명 전통시장명        주소명         위도          경도
# 1      12  동작구  강남시장    상도동 488  37.518749  127.020640
# 2       1  강남구  강남시장  신사동510-11  37.496746  126.953488

# %% [markdown]
# ### 매출 데이터에서 업종이름이 같으면 코드도 같은가?

# %%
# 1만 있으면 같은 것
df_sales.groupby(['서비스_업종_코드_명', '기준_년_코드', '기준_분기_코드', '상권_코드']).count()['서비스_업종_코드'].unique()
# Out:
# array([1], dtype=int64)

# %% [markdown]
# ### 생필품 데이터의 시장주소가 시장주소 데이터의 시장주소에 매핑되는지 확인

# %%
df_market_address[df_market_address['전통시장명'].str.contains('남구로')]
# Out:
#     자치구 코드 자치구명            전통시장명         주소명         위도          경도
# 41       7  구로구  남구로시장(구 구로자율시장)  구로동 730-27  37.490481  126.885048

# %%
necessity_markets = df_necessity['시장/마트 이름'].unique()
none_necessity_markets = set(necessity_markets) - set(market_address_markets)
print(len(necessity_markets), len(none_necessity_markets), none_necessity_markets)
# Out:
# 52 8 {'남구로시장', '방림시장', '방배종합시장', '영동시장', '남성시장', '송화시장', '신창시장', '도곡시장'}

# %%
market_market_address_to_necessity = {}
none_necessity_markets2 = set(none_necessity_markets)


# 창동신창시장은 검색결과 신창시장 맞음
# 보통 남성시장이라고 검색했을 때 이수역의 남성사계시장 의미
pre_market = re.compile(r'(중앙)?(재래)?(골목)?(종합)?시장[가-힣()0-9 ]*')
for none_necessity_market in none_necessity_markets:
    r_market = re.compile(pre_market.sub('', none_necessity_market))
    for market_address_market in market_address_markets:
        if r_market.search(market_address_market):
            print(none_necessity_market, '/', market_address_market)
            market_market_address_to_necessity[market_address_market] = none_necessity_market
            none_necessity_markets2.remove(none_necessity_market)
            break
            
print(market_market_address_to_necessity)
print(len(none_necessity_markets2), none_necessity_markets2)
# Out:
# 남구로시장 / 남구로시장(구 구로자율시장)
# 영동시장 / 영동교골목시장
# 송화시장 / 송화골목시장
# 신창시장 / 창동신창시장
# {'남구로시장(구 구로자율시장)': '남구로시장', '영동교골목시장': '영동시장', '송화골목시장': '송화시장', '창동신창시장': '신창시장'}
# 4 {'방림시장', '방배종합시장', '남성시장', '도곡시장'}

# %% [markdown]
# ### 생필품 데이터의 시장주소가 매출 데이터의 시장주소에 매핑되는지 확인

# %%
none_necessity_markets = set(necessity_markets) - set(sales_markets)
print(len(necessity_markets), len(none_necessity_markets), none_necessity_markets)
# Out:
# 52 15 {'장위골목시장', '수유재래시장', '원당종합시장', '방림시장', '공릉동 도깨비시장', '관악신사시장(신림4동)', '마천중앙시장', '신원시장(신림1동)', '방배종합시장', '영동시장', '남성시장', '송화시장', '대림시장', '용문시장', '신창시장'}

# %%
market_sales_to_necessity = {}
none_necessity_markets2 = set(none_necessity_markets)

# 마천시장 = 마천중앙시장
# 수유전통시장 = 수유재래시장(카카오맵 위치상 거의 같음)
# 장위골목시장 ? 장위전통시장(골목 검색결과 없음)
# 남성시장 != 남성역골목시장(남성사계시장(옛이름 남성시장), 남성역골목시장은 각각 이수, 남성역에 위치)
# 용문시장 ? 용문전통시장(용문전통시장 검색결과 없음)
pre_market = re.compile(r'(중앙)?(재래)?(골목)?(종합)?시장[가-힣()1-9 ]*')
# pre_market = re.compile(r'[()]')
for none_necessity_market in none_necessity_markets:
#     print(pre_market.sub('', none_necessity_market))
    r_market = re.compile(pre_market.sub('', none_necessity_market))
    for sales_market in sales_markets:
        if r_market.search(sales_market):
            print(none_necessity_market, '/', sales_market)
            market_sales_to_necessity[sales_market] = none_necessity_market
            none_necessity_markets2.remove(none_necessity_market)
            break
            
print(market_sales_to_necessity)
print(len(none_necessity_markets2), none_necessity_markets2)
# Out:
# 장위골목시장 / 장위전통시장
# 수유재래시장 / 수유전통시장
# 관악신사시장(신림4동) / 관악신사시장
# 마천중앙시장 / 마천시장
# 신원시장(신림1동) / 신원시장
# 영동시장 / 영동전통시장
# 남성시장 / 남성역골목시장
# 송화시장 / 송화골목시장
# 대림시장 / 대림골목시장
# 용문시장 / 용문전통시장
# 신창시장 / 창동신창시장
# {'장위전통시장': '장위골목시장', '수유전통시장': '수유재래시장', '관악신사시장': '관악신사시장(신림4동)', '마천시장': '마천중앙시장', '신원시장': '신원시장(신림1동)', '영동전통시장': '영동시장', '남성역골목시장': '남성시장', '송화골목시장': '송화시장', '대림골목시장': '대림시장', '용문전통시장': '용문시장', '창동신창시장': '신창시장'}
# 4 {'원당종합시장', '방림시장', '공릉동 도깨비시장', '방배종합시장'}

# %% [markdown]
# ### 시장명 통일

# %%
market_market_address_to_necessity
# Out:
# {'남구로시장(구 구로자율시장)': '남구로시장',
#  '영동교골목시장': '영동시장',
#  '송화골목시장': '송화시장',
#  '창동신창시장': '신창시장'}

# %%
market_sales_to_necessity
# Out:
# {'장위전통시장': '장위골목시장',
#  '수유전통시장': '수유재래시장',
#  '관악신사시장': '관악신사시장(신림4동)',
#  '마천시장': '마천중앙시장',
#  '신원시장': '신원시장(신림1동)',
#  '영동전통시장': '영동시장',
#  '남성역골목시장': '남성시장',
#  '송화골목시장': '송화시장',
#  '대림골목시장': '대림시장',
#  '용문전통시장': '용문시장',
#  '창동신창시장': '신창시장'}

# %%
# 시장이름 통일
df_market_address = df_market_address.replace(market_market_address_to_necessity)
df_sales = df_sales.replace(market_sales_to_necessity)

# %%
df_market_address[df_market_address['전통시장명']=='신창시장']
# Out:
#      자치구 코드 자치구명 전통시장명     주소명         위도          경도
# 293      10  도봉구  신창시장  창동 581  37.640302  127.038832

# %%
df_sales[df_sales['상권_코드_명']=='신창시장']
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 931        2019         1        R       전통시장  1001359    신창시장  CS100001
# 1127       2019         1        R       전통시장  1001359    신창시장  CS200003
# 3405       2019         1        R       전통시장  1001359    신창시장  CS100010
# 3441       2019         1        R       전통시장  1001359    신창시장  CS200008
# 3731       2019         1        R       전통시장  1001359    신창시장  CS300033
# ...         ...       ...      ...        ...      ...     ...       ...
# 154207     2014         4        R       전통시장  1001359    신창시장  CS300031
# 154209     2014         4        R       전통시장  1001359    신창시장  CS300036
# 155500     2014         4        R       전통시장  1001359    신창시장  CS300017
# 160670     2014         4        R       전통시장  1001359    신창시장  CS200038
# 161755     2014         4        R       전통시장  1001359    신창시장  CS100010
#
#        서비스_업종_코드_명  분기당_매출_금액  분기당_매출_건수  ...  시간대_건수~24_매출_건수  남성_매출_건수  \
# ...

# %% [markdown]
# ### 필요없는 컬럼 제거 및 이름 통일

# %%
# 컬럼이름변환, 필요없는 컬럼 삭제
df_necessity = df_necessity.rename({'시장/마트 이름': '시장이름', '자치구 이름': '자치구'}, axis=1)
df_necessity = df_necessity.drop(['점검일자', '시장/마트 번호', '품목 번호', '시장유형 구분(시장/마트) 코드', '시장유형 구분(시장/마트) 이름', '자치구 코드'], axis=1)

# %%
df_necessity.head()
# Out:
#       일련번호    시장이름       품목 이름   실판매규격  가격(원)     년도-월         비고  자치구
# 0  1621162    통인시장  양파(1.5kg망)     1kg   2000  2020-12     국내산,무안  종로구
# 1  1628949  방배종합시장          호박  1개268g   1500  2020-12  국내산/인큐베이터  서초구
# 4  1622882    통인시장  양파(1.5kg망)     1kg   2000  2020-12     국내산,무안  종로구
# 6  1622883    통인시장    상추(100g)    400g   3000  2020-12    국내산,적상추  종로구
# 8  1622885    통인시장   호박(인큐베이터)      1개   1000  2020-12       국내산,  종로구

# %%
df_market_address = df_market_address.rename({'전통시장명': '시장이름', '자치구명': '자치구'}, axis=1)
df_market_address = df_market_address.drop(['자치구 코드'], axis=1)

# %%
df_market_address.head()
# Out:
#    자치구            시장이름          주소명         위도          경도
# 0  은평구            갈현시장   갈현동 424-16  37.623587  126.917385
# 1  동작구            강남시장      상도동 488  37.518749  127.020640
# 2  강남구            강남시장    신사동510-11  37.496746  126.953488
# 3  강남구       강남역 지하도상가     역삼동821-1  37.498595  127.028026
# 4  서초구  강남터미널지하도상점가1구역  서초구 반포동 163  37.500478  126.986060

# %%
df_sales = df_sales.rename({'상권_코드_명': '시장이름', '서비스_업종_코드_명': '업종'}, axis=1)
df_sales = df_sales.drop(['상권_구분_코드', '상권_구분_코드_명', '상권_코드', '서비스_업종_코드'], axis=1)

# %%
df_sales.head()
# Out:
#     기준_년_코드  기준_분기_코드    시장이름     업종   분기당_매출_금액  분기당_매출_건수  주중_매출_비율  \
# 2      2019         1    영도시장   섬유제품     4038928         33       100
# 6      2019         1  암사종합시장  수산물판매  1712543938     108896        64
# 14     2019         1  서울약령시장    한의원  3329153658      38642        76
# 15     2019         1    경동시장   육류판매  4587060783      84286        65
# 28     2019         1   답십리시장    미용실   100328154       2550        67
#
#     주말_매출_비율  월요일_매출_비율  화요일_매출_비율  ...  시간대_건수~24_매출_건수  남성_매출_건수  여성_매출_건수  \
# 2          0         49          0  ...                0        17         0
# 6         36         15          8  ...              511     40273     68502
# 14        24         17         13  ...               26     14251     24366
# 15        35          8         14  ...                5     31843     51739
# 28        33          9          3  ...                0      1470      1080
#
#     연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  \
# ...

# %% [markdown]
# ### 생필품 데이터와 매출 데이터가 join할 수 있도록 만들기
# - 시장이름은 이미 통일함
# - '품목 이름', '가격(원)', '년도-월'에서 결측치 제거
# - 품목이름과 업종이름 매칭 필요(ex 생필품에서 양파(1.5kg망) -> (양파, 청과상))
# - 년도-분기로 통일필요(ex 생필품에서 2019-03 -> (2019-03, 2019-1분기), 매출에서 (2019, 1) -> 2019-1분기)

# %%
df_necessity['품목 이름'].unique()
# Out:
# array(['양파(1.5kg망)', '호박', '상추(100g)', '호박(인큐베이터)', '쇠고기(한우,불고기)',
#        '돼지고기(생삼겹살)', '닭고기(육계)', '달걀(10개)', '달걀(30개)', '조기(냉동,수입산)',
#        '명태(러시아,냉동)', '오징어(생물,국산)', '고등어(생물,국산)', '무(세척무, 중)', '오이',
#        '사과(부사, 300g)', '배추(중간)', '배(신고, 600g)', '오징어', '명태', '배추', '무',
#        '닭고기', '돼지고기', '쇠고기', '양파', '조기', '사과', '배', '고등어', '상추',
#        '배추(2.5~3kg)', '조기(국산,생물)', '동태', '오이(다다기)', '애호박', '무(1kg)',
#        '명태(생물,수입산)', '쇠고기(한우1등급)', '명태(냉동,수입산)', '조기(생물,국산)',
#        '명태(45cm,수입산)', '조기(국산,냉동)', '돼지고기(삼겹살)', '닭고기(중간)', '닭고기(토종닭)',
#        '배추(국산)', '배(신고)', '양파(작은망)', '오징어(냉동,국산)', '무(세척무)', '배(중품)',
#        '호박(인큐베이터),중간', '쇠고기(육우,불고기)', '조기(냉동,국산)', '배(신고),중급(대)',
#        '사과(부사)', '냉동참조기(20cm,국산)', '고등어(냉동,국산)', '달걀', '사과(부사),중급(대)',
#        '명태(생물,국산)', '달걀(왕란)', '오징어(냉동,수입산)', nan, '고등어(생물,수입산)',
#        '조기(생물,수입산)', '사과(중품)', '조기(중국산,생물)', '고등어(30cm,국산)',
#        '오징어(생물,수입산)', '고등어(냉동,수입산)', '오징어(냉동)', '배(중품),신고',
# ...

# %%
df_sales['업종'].unique()
# Out:
# array(['섬유제품', '수산물판매', '한의원', '육류판매', '미용실', '한식음식점', '호프-간이주점', '일반의류',
#        '네일숍', '골프연습장', '슈퍼마켓', '중식음식점', '철물점', '피부관리실', '분식전문점', '인테리어',
#        '치킨전문점', '고시원', '문구', '스포츠 강습', '의료기기', '커피-음료', '시계및귀금속', '편의점',
#        '당구장', '양식음식점', '운동/경기용품', '패스트푸드점', '노래방', '일반교습학원', '의약품',
#        '애완동물', '반찬가게', '가방', '청과상', '일반의원', '안경', '세탁소', '일식음식점', '핸드폰',
#        '제과점', '예술학원', '화초', '화장품', '스포츠클럽', '치과의원', '서적', '신발', '가전제품',
#        '자전거 및 기타운송장비', '미곡판매', '완구', '외국어학원', '전자상거래업', '조명용품',
#        '컴퓨터및주변장치판매', '여관', '가구', '자동차수리', 'PC방', '가전제품수리', '자동차미용', '사진관',
#        '한복점', '유아의류', '변호사사무소', '예술품', '악기', '독서실', '부동산중개업', '볼링장',
#        '여행사', '세무사사무소', '통신기기수리', '자동차부품', '주유소', '법무사사무소', '회계사사무소'],
#       dtype=object)

# %%
df_necessity = df_necessity.dropna(subset=['품목 이름', '가격(원)', '년도-월'])
print(df_necessity['품목 이름'].isnull().values.any())
print(df_necessity['가격(원)'].isnull().values.any())
print(df_necessity['년도-월'].isnull().values.any())
# Out:
# False
# False
# False

# %%
df_necessity.head()
# Out:
#       일련번호    시장이름       품목 이름   실판매규격  가격(원)     년도-월         비고  자치구
# 0  1621162    통인시장  양파(1.5kg망)     1kg   2000  2020-12     국내산,무안  종로구
# 1  1628949  방배종합시장          호박  1개268g   1500  2020-12  국내산/인큐베이터  서초구
# 4  1622882    통인시장  양파(1.5kg망)     1kg   2000  2020-12     국내산,무안  종로구
# 6  1622883    통인시장    상추(100g)    400g   3000  2020-12    국내산,적상추  종로구
# 8  1622885    통인시장   호박(인큐베이터)      1개   1000  2020-12       국내산,  종로구

# %%
item_names = set()
re_item = re.compile('[(,][가-힣0-9a-zA-Z ,.~]*[)]?')
for item in df_necessity['품목 이름'].unique():
    item_name = re_item.sub('', item)
    item_names.add(item_name)
print(item_names)
# Out:
# {'동태', '명태', '닭고기', '배', '냉동참조기', '상추', '호박', '양파', '갈치', '오징어', '사과', '달걀', '삼겹살', '고등어', '조기', '배추', '애호박', '돼지고기', '오이', '쇠고기', '무'}

# %%
# item_names의 결과에 업종을 수작업으로 매핑
# category = ['수산물판매', '육류판매', '미곡판매', '청과상']
item_to_category = {
    '애호박': '청과상', 
    '오징어': '수산물판매', 
    '상추': '청과상', 
    '사과': '청과상', 
    '오이': '청과상', 
    '달걀': '육류판매', 
    '돼지고기': '육류판매', 
    '냉동참조기': '수산물판매', 
    '양파': '청과상', 
    '조기': '수산물판매', 
    '동태': '수산물판매', 
    '호박': '청과상', 
    '쇠고기': '육류판매', 
    '고등어': '수산물판매', 
    '닭고기': '육류판매', 
    '명태': '수산물판매', 
    '무': '청과상', 
    '배': '청과상', 
    '배추': '청과상',
    '삼겹살': '육류판매',
    '갈치': '수산물판매',
}

# %%
df_necessity[df_necessity['품목 이름'].str.contains('^호박')]
# Out:
#           일련번호      시장이름      품목 이름     실판매규격  가격(원)     년도-월         비고  자치구
# 1      1628949    방배종합시장         호박    1개268g   1500  2020-12  국내산/인큐베이터  서초구
# 8      1622885      통인시장  호박(인큐베이터)        1개   1000  2020-12       국내산,  종로구
# 74     1624571      통인시장  호박(인큐베이터)        1개   1200  2020-12    국내산,애호박  종로구
# 84     1629967      통인시장  호박(인큐베이터)        1개   1500  2020-12  국내산,인큐애호박  종로구
# 188    1626779  방학동도깨비시장         호박  1개(340g)   1400  2020-12   국냇.인큐베이터  도봉구
# ...        ...       ...        ...       ...    ...      ...        ...  ...
# 96488   403304    수유재래시장         호박        1개   1500  2013-01        NaN  강북구
# 96520   403336    자양골목시장  호박(인큐베이터)        1개   2300  2013-01        빛그린  광진구
# 96568   403384      남문시장  호박(인큐베이터)        1개   1500  2013-01        NaN  금천구
# 97048   406472    마천중앙시장  호박(인큐베이터)        1개   1800  2013-01        논개   송파구
# 97064   406488      방이시장  호박(인큐베이터)        1개   1800  2013-01        논개   송파구
#
# [4496 rows x 8 columns]

# %%
# 품목 이름, 업종 매칭 완료
condlist = []
choicelist = []

for item, category in item_to_category.items():
    condlist.append(df_necessity['품목 이름'].str.contains('^' + item))
    choicelist.append(category)

df_necessity['업종'] = np.select(condlist, choicelist)

# %%
df_necessity['업종'].unique()
# Out:
# array(['청과상', '육류판매', '수산물판매'], dtype=object)

# %%
# 생필품 데이터에서 년도-분기 매칭 완료
condlist = []
choicelist = []

for year_month in df_necessity['년도-월'].unique():
    year, month = year_month.split('-')
    quarter = ''
    if month in {'01', '02', '03'}:
        quarter = '1분기'
    elif month in {'04', '05', '06'}:
        quarter = '2분기'
    elif month in {'07', '08', '09'}:
        quarter = '3분기'
    elif month in {'10', '11', '12'}:
        quarter = '4분기'
    condlist.append(df_necessity['년도-월'] == year_month)
    choicelist.append(year + '-' + quarter)

df_necessity['년도-분기'] = np.select(condlist, choicelist)

# %%
df_necessity['년도-분기'].unique()
# Out:
# array(['2020-4분기', '2020-3분기', '2020-2분기', '2020-1분기', '2019-4분기',
#        '2019-3분기', '2019-2분기', '2019-1분기', '2018-4분기', '2018-3분기',
#        '2018-2분기', '2018-1분기', '2017-4분기', '2017-3분기', '2017-2분기',
#        '2017-1분기', '2016-4분기', '2016-3분기', '2016-2분기', '2016-1분기',
#        '2015-4분기', '2015-3분기', '2015-2분기', '2015-1분기', '2014-4분기',
#        '2014-3분기', '2014-2분기', '2014-1분기', '2013-4분기', '2013-3분기',
#        '2013-2분기', '2013-1분기'], dtype=object)

# %%
# 매출 데이터에서 년도-분기 매칭 완료
condlist = []
choicelist = []
df_sales[['기준_년_코드', '기준_분기_코드']].drop_duplicates().values
for row in df_sales[['기준_년_코드', '기준_분기_코드']].drop_duplicates().values:
    year, quarter = row[0], row[1]
    condlist.append((df_sales['기준_년_코드']==year) & (df_sales['기준_분기_코드']==quarter))
    choicelist.append(str(year) + '-' + str(quarter) + '분기')
    
df_sales['년도-분기'] = np.select(condlist, choicelist)

# %%
df_sales['년도-분기'].unique()
# Out:
# array(['2019-1분기', '2019-2분기', '2019-3분기', '2019-4분기', '2018-1분기',
#        '2018-2분기', '2018-3분기', '2018-4분기', '2017-1분기', '2017-2분기',
#        '2017-3분기', '2017-4분기', '2016-1분기', '2016-2분기', '2016-3분기',
#        '2016-4분기', '2015-1분기', '2015-2분기', '2015-3분기', '2015-4분기',
#        '2014-1분기', '2014-2분기', '2014-3분기', '2014-4분기'], dtype=object)

# %% [markdown]
# ### 생필품, 매출, 시장주소를 통일된 시장이름으로 join

# %%
df_necessity.head()
# Out:
#       일련번호    시장이름       품목 이름   실판매규격  가격(원)     년도-월         비고  자치구   업종  \
# 0  1621162    통인시장  양파(1.5kg망)     1kg   2000  2020-12     국내산,무안  종로구  청과상
# 1  1628949  방배종합시장          호박  1개268g   1500  2020-12  국내산/인큐베이터  서초구  청과상
# 4  1622882    통인시장  양파(1.5kg망)     1kg   2000  2020-12     국내산,무안  종로구  청과상
# 6  1622883    통인시장    상추(100g)    400g   3000  2020-12    국내산,적상추  종로구  청과상
# 8  1622885    통인시장   호박(인큐베이터)      1개   1000  2020-12       국내산,  종로구  청과상
#
#       년도-분기
# 0  2020-4분기
# 1  2020-4분기
# 4  2020-4분기
# 6  2020-4분기
# 8  2020-4분기

# %%
df_sales.head()
# Out:
#     기준_년_코드  기준_분기_코드    시장이름     업종   분기당_매출_금액  분기당_매출_건수  주중_매출_비율  \
# 2      2019         1    영도시장   섬유제품     4038928         33       100
# 6      2019         1  암사종합시장  수산물판매  1712543938     108896        64
# 14     2019         1  서울약령시장    한의원  3329153658      38642        76
# 15     2019         1    경동시장   육류판매  4587060783      84286        65
# 28     2019         1   답십리시장    미용실   100328154       2550        67
#
#     주말_매출_비율  월요일_매출_비율  화요일_매출_비율  ...  남성_매출_건수  여성_매출_건수  연령대_10_매출_건수  \
# 2          0         49          0  ...        17         0             0
# 6         36         15          8  ...     40273     68502           116
# 14        24         17         13  ...     14251     24366            10
# 15        35          8         14  ...     31843     51739            30
# 28        33          9          3  ...      1470      1080            50
#
#     연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  연령대_60_이상_매출_건수  \
# ...

# %%
df_market_address.head()
# Out:
#    자치구            시장이름          주소명         위도          경도
# 0  은평구            갈현시장   갈현동 424-16  37.623587  126.917385
# 1  동작구            강남시장      상도동 488  37.518749  127.020640
# 2  강남구            강남시장    신사동510-11  37.496746  126.953488
# 3  강남구       강남역 지하도상가     역삼동821-1  37.498595  127.028026
# 4  서초구  강남터미널지하도상점가1구역  서초구 반포동 163  37.500478  126.986060

# %%
df_necessity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171039 entries, 0 to 97072
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   일련번호    171039 non-null  int64
#  1   시장이름    171039 non-null  object
#  2   품목 이름   171039 non-null  object
#  3   실판매규격   171039 non-null  object
#  4   가격(원)   171039 non-null  int64
#  5   년도-월    171039 non-null  object
#  6   비고      124320 non-null  object
#  7   자치구     171039 non-null  object
#  8   업종      171039 non-null  object
#  9   년도-분기   171039 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 14.4+ MB

# %%
df_market_address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     330 non-null    object
#  1   시장이름    330 non-null    object
#  2   주소명     330 non-null    object
#  3   위도      330 non-null    float64
#  4   경도      330 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 13.0+ KB

# %%
df_necessity_market_address = df_necessity.merge(df_market_address, how='left', on=['시장이름'], suffixes=('_necessity', '_market_address'))

# %%
df_necessity_market_address[df_necessity_market_address['자치구_necessity']!=df_necessity_market_address['자치구_market_address']].dropna()
# Out:
#            일련번호  시장이름       품목 이름       실판매규격  가격(원)     년도-월            비고  \
# 561     1626844  대림시장          양파       1.5kg   3000  2020-12           무안
# 849     1624958  우림시장          양파   1망(1.5kg)   3000  2020-12           국내산
# 851     1624956  우림시장          배추  1포기(2800g)   2500  2020-12           국내산
# 853     1624954  우림시장          사과   1봉(2100g)  14000  2020-12    국내산 부사 8개입
# 859     1626846  대림시장          오이   1개 (200g)    800  2020-12       다다기 국내산
# ...         ...   ...         ...         ...    ...      ...           ...
# 174200   403051  대림시장     닭고기(육계)   1마리(1.kg)   5500  2013-01           하림
# 174202   403052  대림시장      달걀(왕란)         10개   1833  2013-01  왕란 30개 5500원
# 174204   403053  대림시장  조기(냉동,수입산)   1마리(23cm)   3500  2013-01           부세
# 174208   403055  대림시장  오징어(생물,국산)   1마리(35cm)   1500  2013-01            동해
# 174210   403056  대림시장  고등어(냉동,국산)   1마리(30cm)   3000  2013-01            부산
#
# ...

# %%
df_necessity_market_address[df_necessity_market_address['자치구_necessity']!=df_necessity_market_address['자치구_market_address']].dropna()[['시장이름', '주소명', '자치구_necessity', '자치구_market_address']].drop_duplicates()
# Out:
#         시장이름          주소명 자치구_necessity 자치구_market_address
# 561     대림시장     대림동963-5           은평구               영등포구
# 849     우림시장    난곡동 637-1           중랑구                관악구
# 147449  영동시장  자양동 246-111           강남구                광진구
